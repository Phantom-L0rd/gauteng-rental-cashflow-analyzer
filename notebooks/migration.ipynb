# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import sys
print(sys.executable)
# Out:
# /home/codespace/.python/current/bin/python

# %%
PARQUET_PATH = "../data/2_silver_cleaned/type=rent/listings.parquet"
df = pd.read_parquet(PARQUET_PATH)

# %%
df.head()
# Out:
#   listing_number                  scrape_at   price                title  \
# 0      116898033 2026-04-01 22:25:02.733103  5600.0  2 Bedroom Apartment
# 1      115921453 2026-04-01 22:25:02.732737  5600.0  2 Bedroom Apartment
# 2      115895380 2026-04-01 22:23:27.611216  4390.0  1 Bedroom Apartment
# 3      116698560 2026-04-01 22:23:27.610574  8500.0      4 Bedroom House
# 4      116970242 2026-04-01 22:23:27.610239  4500.0  1 Bedroom Apartment
#
#         type      suburb        city            munis  bedrooms  bathrooms  \
# 0  Apartment  pyramid ah  wonderboom  city of tshwane       2.0        2.0
# 1  Apartment  pyramid ah  wonderboom  city of tshwane       2.0        2.0
# 2  Apartment  westonaria  westonaria        west rand       1.0        1.0
# 3      House  westonaria  westonaria        west rand       4.0        1.0
# 4  Apartment  westonaria  westonaria        west rand       1.0        1.0
#
#    parking  floor_size  is_estate  has_security  is_modern  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26501 entries, 0 to 26500
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   listing_number   26501 non-null  str
#  1   scrape_at        26501 non-null  datetime64[ns]
#  2   price            26501 non-null  float64
#  3   title            26501 non-null  str
#  4   type             26501 non-null  str
#  5   suburb           26501 non-null  str
#  6   city             26501 non-null  str
#  7   munis            26501 non-null  str
#  8   bedrooms         26501 non-null  float64
#  9   bathrooms        26501 non-null  float64
#  10  parking          26501 non-null  float64
#  11  floor_size       26501 non-null  float64
#  12  is_estate        26501 non-null  int64
#  13  has_security     26501 non-null  int64
#  14  is_modern        26501 non-null  int64
#  15  location         26501 non-null  str
#  16  total_rooms      26501 non-null  float64
# ...

# %%
df[df['price_sqm'] < 30].shape
# Out:
# (3511, 23)

# %%
df.columns
# Out:
# Index(['listing_number', 'scrape_at', 'price', 'title', 'type', 'suburb',
#        'city', 'munis', 'bedrooms', 'bathrooms', 'parking', 'floor_size',
#        'is_estate', 'has_security', 'is_modern', 'location', 'total_rooms',
#        'price_sqm', 'z_score', 'suburb_avg_rent', 'city_avg_rent',
#        'muni_avg_rent', 'is_luxury'],
#       dtype='str')
